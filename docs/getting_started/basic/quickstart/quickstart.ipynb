# %% [markdown]
# # Quickstart
#
# Welcome to the quickstart. This simple getting started will walk you through installing FiftyOne, loading the SDK, adding and examining a Dataset, and then viewing the Dataset in the FiftyOne Application. You can think of this as a "smoke test" to make sure everything is installed and working properly
